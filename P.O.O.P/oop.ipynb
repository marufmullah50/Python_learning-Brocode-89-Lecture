# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# #object = A "bundle" of related attributes(Variables) and methods (functions)
#
#
# #example     phone , cup , book
#
# #You need a "class" to create many objects
#
# #Class = (blueprint) used to design the structure and layout of an object

# %%
class Car:
    def __init__(self,model,year,color,for_sale):
        self.model =model
        self.year = year
        self.color = color
        self.for_sale =for_sale


car1 =Car("Mustang", 2024 , "red",False)
car2 = Car("Corvette",2025,"blue",True)
car3 = Car ("Charger", 2026, "Yellow", True)
print(car1)# memory address of car1

#attribute
print(car1.model)
print(car1.year)
print(car1.color)
print(car1.for_sale)
# Out:
# ...
# Mustang
# 2024
# red
# False

# %% [markdown]
# #Importing from different file

# %%
from classes import Phone
phone1 =Phone("iphone 17 Air", 2025 , "White",True)
model =phone1.model
release =phone1.year
color =phone1.color
Available =phone1.for_sale
print(f"Phone model:{model}")
print("Release year",release)
print("Phone color",color)
print("Available for sale:",Available)
# Out:
# Phone model:iphone 17 Air
# Release year 2025
# Phone color White
# Available for sale: True

# %% [markdown]
# #Methods are actions within class that a class can perform
#
# #functions in class besides the init

# %%
from class2 import Car
car1 =Car("Mustang", 2024 , "red",False)
car1.describe()
car1.drive()
car1.stop()

print("\n")
car2 = Car("Corvette",2025,"blue",True)
car2.describe()
car2.drive()
car2.stop()
# Out:
# 2024 red Mustang
# You will drive the red Mustang
# You will stop the red Mustang
#
#
# 2025 blue Corvette
# You will drive the blue Corvette
# You will stop the blue Corvette

# %% [markdown]
# #Video 48 CLass variables
#
# #Class variables  = shared among all instances of a class
# sefined outside the constructor
# Allow you to share data amaong all objects created from that  class

# %%
class Student:
    class_year = 2025 # class variable
    num_students = 0
    def __init__ (self , name , age):
        self.name = name
        self.age = age
        Student.num_students +=1 #class variable


student1 = Student("Chow",22)
student2 =Student("lee",23)
student3 =Student("Li",26)
print(f"First student name:{student1.name} and age : {student1.age}")

print(f"Second student name:{student2.name} and age : {student2.age}")
print("\n")
#In here studen1. , student2. And class name-> Student. will give same result
# Best practice is to use class name
print("Student Graduating Year:", Student.class_year)

print("Number of student:",Student.num_students)# how many student variable made
# Out:
# First student name:Chow and age : 22
# Second student name:lee and age : 23
#
#
# Student Graduating Year: 2025
# Number of student: 3

# %% [markdown]
# #Inheritance = Allows a class to inherit attributes and methods from another class.
#
# #Helps with code reusability and extensibility
#
# #class child(parent)

# %%
# Example
class Father:
    height =182
    color = "white"
class Son(Father):
    pass

# %%
class Animal:
    def __init__(self,name):
        self.name = name
        self.is_alive = True
    def eat(self):
        print(f"{self.name} is eating")
    def sleep(self):
        print(f"{self.name} is sleeping")
#Child class
class Dog(Animal):
    pass
class Cat(Animal):
    pass
class Mouse(Animal):
    pass

#Even though the child class are empty they automatically has their parent class 
#Attributes

dog = Dog("Bull Dog")
cat = Cat("Tom")
mouse = Mouse("Jerry")
print(dog.name)
print(dog.is_alive)
dog.eat()
dog.sleep()
# same for others as well
# Out:
# Bull Dog
# True
# Bull Dog is eating
# Bull Dog is sleeping

# %% [markdown]
# #Multiple Inheritance = inherit from more than one parent class ,
#
#                            C(A,B)
#
# #Multilevel inheritance = inherit from a parent which inherits from another parent
#
#                         C(B) <- B(A) <- A

# %%
class Predator:
    def hunt(self):
        print("This animal Hunt")
class Prey:
    def flee(self):
        print("This Animal Flee")

class Rabbit(Prey):
    pass
class Hawk(Predator):
    pass
class Fish(Predator,Prey):
    pass

rabbit = Rabbit()
hawk=Hawk()
fish =Fish()

print("Rabbit")
rabbit.flee()
print("\n Hawk")
hawk.hunt()
print("\nFish")
fish.hunt()
fish.flee()
# Out:
# Rabbit
# This Animal Flee
#
#  Hawk
# This animal Hunt
#
# Fish
# This animal Hunt
# This Animal Flee

# %% [markdown]
# #Multilevel

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def eat(self):
        print(f"This {self.name} is eating")
    def sleep(self):
        print(f"This {self.name} is sleeping")

class Predator(Animal):
    def hunt(self):
        print(f"This {self.name} Hunt")
class Prey(Animal):
    def flee(self):
        print(f"This {self.name} Flee")

class Rabbit(Prey): # it inherit from parent which inherit from another parent
    pass             # Grand parent level inheritence
class Hawk(Predator):
    pass
class Fish(Predator,Prey):
    pass

rabbit = Rabbit("Bunny")
hawk=Hawk("Tony")
fish =Fish("Nemo")
rabbit.eat()
fish.hunt()
# Out:
# This Bunny is eating
# This Nemo Hunt

# %% [markdown]
# #Abstract Class: A class that cannot be instantiated on its own; Meant to be subclassed. They cannot abstract methods , which are declared but have no implementation.
#
# #Abstract classes Benefits:
#
# 1.Prevents instantiation of the class itself
#
# 2.Requires children to use inherited abstract methods

# %%
from abc import ABC,abstractmethod

class vehicle(ABC):
    @abstractmethod
    def go(self): #Method to inherit for child thats why @abstractmethod used to remember
        print("You shall pass")
    @abstractmethod
    def stop(self):
        print("You must stop")
class Boat(vehicle):
    def go(self): 
        print("You shall pass")
    def stop(self):
        print("You must stop")

class Bike(vehicle):
    def stop(self):
        print("You must stop")
        #Here now if i try bike=Bike() it will say error
        #Cause i didn't include go stop both like parent class

boat =Boat()
boat.go()
boat.stop()
# Out:
# You shall pass
# You must stop

# %% [markdown]
# #super() = Function in a child class to call methods from a parent class (superclass).
#
# #Allows you to extend the functionality of the inherited methods

# %%
class Shape:#Parent
    def __init__(self,color,filled):
        self.color =color
        self.filled = filled #Using super in child class the i won't require to initialize it

class Circle(Shape):
    def __init__(self,color,filled,radius):
        super().__init__(color,filled)
        self.radius =radius

class Square(Shape):
    def __init__(self,color,filled,width):
        super().__init__(color,filled)
        self.width =width

class Triangle(Shape):
    def __init__(self,color,filled,width,height):
        super().__init__(color,filled)
        self.width =width
        self.height =height

circle =Circle("red","filled",5)
print(f"circle color is:{circle.color} , it is {circle.filled} and the radius is {circle.radius}cm")

sq=Square("red","not filled",10)
print(f"Square color is:{sq.color} , it is {sq.filled} and the width is {sq.width}cm")


tri=Triangle("red","notfilled",10,20)
print(f"Triangle color is:{tri.color} , it is {tri.filled}, the width is {tri.width}cm and height is {tri.height}cm")
# Out:
# circle color is:red , it is filled and the radius is 5cm
# Square color is:red , it is not filled and the width is 10cm
# Triangle color is:red , it is notfilled, the width is 10cm and height is 20cm

# %%
class Shape:#Parent
    def __init__(self,color,filled):
        self.color =color
        self.filled = filled #Using super in child class the i won't require to initialize it
    def describe(self):
        print(f"It is {self.color} and {self.filled}")
class Circle(Shape):
    def __init__(self,color,filled,radius):
        Shape.__init__(self,color,filled)
        self.radius =radius

class Square(Shape):
    def __init__(self,color,filled,width):
        super().__init__(color, filled) # instead can use Shape.__init__(self,color,filled)
        self.width =width                     #extra is Shape.__init(self,color,filled) -> self in __init__

class Triangle(Shape):
    def __init__(self,color,filled,width,height):
        super().__init__(color,filled)
        self.width =width
        self.height =height

circle =Circle("black","filled",5)
print(f"circle color is:{circle.color} , it is {circle.filled} and the radius is {circle.radius}cm")

sq=Square("red","not filled",10)
print(f"Square color is:{sq.color} , it is {sq.filled} and the width is {sq.width}cm")


tri=Triangle("yellow","notfilled",10,20)
print(f"Triangle color is:{tri.color} , it is {tri.filled}, the width is {tri.width}cm and height is {tri.height}cm")


print("\n")
circle.describe()
sq.describe()
# Out:
# circle color is:black , it is filled and the radius is 5cm
# Square color is:red , it is not filled and the width is 10cm
# Triangle color is:yellow , it is notfilled, the width is 10cm and height is 20cm
#
#
# It is black and filled
# It is red and not filled

# %%
class Shape:#Parent
    def __init__(self,color,filled):
        self.color =color
        self.filled = filled #Using super in child class the i won't require to initialize it
    def describe(self):
        print(f"It is {self.color} and {self.filled}")
class Circle(Shape):
    def __init__(self,color,filled,radius):
        Shape.__init__(self,color,filled)
        self.radius =radius
    def describe(self):
        print(f"Area is {3.14* self.radius**2} cm^2") #If its called  it will use child function
class Square(Shape):
    def __init__(self,color,filled,width):
        super().__init__(color, filled) # instead can use Shape.__init__(self,color,filled)
        self.width =width                     #extra is Shape.__init(self,color,filled) -> self in __init__

class Triangle(Shape):
    def __init__(self,color,filled,width,height):
        super().__init__(color,filled)
        self.width =width
        self.height =height

circle =Circle("black","filled",5)
circle.describe() # here actually child method called
# Out:
# Area is 78.5 cm^2

# %%
class Shape:#Parent
    def __init__(self,color,filled):
        self.color =color
        self.filled = filled #Using super in child class the i won't require to initialize it
    def describe(self):
        print(f"It is {self.color} and {self.filled}")
class Circle(Shape):
    def __init__(self,color,filled,radius):
        Shape.__init__(self,color,filled)
        self.radius =radius
    def describe(self):
        super().describe() #Now while called both describe called
        print(f"Area is {3.14* self.radius**2} cm^2")
        
class Square(Shape):
    def __init__(self,color,filled,width):
        super().__init__(color, filled) # instead can use Shape.__init__(self,color,filled)
        self.width =width                     #extra is Shape.__init(self,color,filled) -> self in __init__

class Triangle(Shape):
    def __init__(self,color,filled,width,height):
        super().__init__(color,filled)
        self.width =width
        self.height =height

circle =Circle("black","filled",5)
circle.describe() # here both parentand child method called
# Out:
# It is black and filled
# Area is 78.5 cm^2

# %% [markdown]
# #Polymorphism = Greek word that means to have many forms or faces
#
#                          poly = many
#                          morphe = form
# #Two ways to achieve Polymorphism
#
# 1.Inheritance = An Object could be treated of the same type as a parent class
#
# 2."Duck typing" = object must have necessary attributes/methods

# %%
class Shape1: #Parent
    @abstractmethod
    def area (self):
        pass

class Circle1(Shape1):
    def __init__(self,radius):
        self.radius =radius
    
    def area(self):
        return 3.14*self.radius**2

class Square1(Shape1):
    def __init__(self,width):
        self.width = width
    
    def area(self):
        return self.width**2

class Triangle1(Shape1):
    def __init__(self,base,height):
        self.base =base
        self.height =height
    
    def area(self):
        return self.base * self.height * 0.5

shapes =[Circle1(4),Square1(5),Triangle1(6,7)]#Here child treated as parent

for shape in shapes:
    print(f"{shape.area()}cm\u00b2") #\u00bx x=exponential
# Out:
# 50.24cm²
# 25cm²
# 21.0cm²

# %%
#with grand parental
class Shape1:
    @abstractmethod
    def area (self):
        pass

class Circle1(Shape1):
    def __init__(self,radius):
        self.radius =radius
    
    def area(self):
        return 3.14*self.radius**2

class Square1(Shape1):
    def __init__(self,width):
        self.width = width
    
    def area(self):
        return self.width**2

class Triangle1(Shape1):
    def __init__(self,base,height):
        self.base =base
        self.height =height
    
    def area(self):
        return self.base * self.height * 0.5

class Pizza1(Circle1):
    def __init__(self,toppings ,radius):
        super().__init__(radius)
        self.toppings =toppings

shapes =[Circle1(4),Square1(5),Triangle1(6,7),Pizza1("Cheese",15)] #Child and grand child as parent

for shape in shapes:
    print(f"{shape.area()}cm\u00b2") #\u00bx x=exponential
# Out:
# 50.24cm²
# 25cm²
# 21.0cm²
# 706.5cm²

# %% [markdown]
# #Duck typing = Another way to achieve polymorphism besides Inheritance object
#                must have the minimum necessary attributes/methods
#
#                "If it looks like a duck and quacks like a duck
#                it must be a duck"

# %%
class Animal1:
    alive =True

#Child class
class Dog1(Animal1):
    def speak(self):
        print("Woof")
class Cat1(Animal1):
    def speak(self):
        print("Meow")
    


animals = [Dog1(),Cat1()]
for animal in animals:
    animal.speak()
# Out:
# Woof
# Meow

# %% [markdown]
# #error
#
# #no similar method in mouse
#
# #Attribute error

# %%
class Animal1:
    alive =True

#Child class
class Dog1(Animal1):
    def speak(self):
        print("Woof")
class Cat1(Animal1):
    def speak(self):
        print("Meow")
    

class Mouse1:
    def sound(self):
        print("squeak")


    
animals = [Dog1(),Cat1(),Mouse1()]
for animal in animals:
    animal.speak()
# Out:
# Woof
# Meow
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 21
#      19 animals = [Dog1(),Cat1(),Mouse1()]
#      20 for animal in animals:
# ---> 21     animal.speak()
#
# AttributeError: 'Mouse1' object has no attribute 'speak'

# %% [markdown]
# #Corrected
#
# #Renamed sound to speak

# %%
class Animal1:
    alive =True

#Child class
class Dog1(Animal1):
    def speak(self):
        print("Woof")
class Cat1(Animal1):
    def speak(self):
        print("Meow")
    

class Mouse1:
    def speak(self):
        print("squeak")


    
animals = [Dog1(),Cat1(),Mouse1()]
for animal in animals:
    animal.speak()
# Out:
# Woof
# Meow
# squeak

# %% [markdown]
# #alive attribute error in mouse

# %%
class Animal1:
    alive =True

#Child class
class Dog1(Animal1):
    def speak(self):
        print("Woof")
class Cat1(Animal1):
    def speak(self):
        print("Meow")
    

class Mouse1:
    def speak(self):
        print("squeak")


    
animals = [Dog1(),Cat1(),Mouse1()]
for animal in animals:
    animal.speak()
    print(animal.alive)
# Out:
# Woof
# True
# Meow
# True
# squeak
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 22
#      20 for animal in animals:
#      21     animal.speak()
# ---> 22     print(animal.alive)
#
# AttributeError: 'Mouse1' object has no attribute 'alive'

# %% [markdown]
# #Adding Attribute

# %%
class Animal1:
    alive =True

#Child class
class Dog1(Animal1):
    def speak(self):
        print("Woof")
class Cat1(Animal1):
    def speak(self):
        print("Meow")
    

class Mouse1:
    alive =True
    def speak(self):
        print("squeak")


    
animals = [Dog1(),Cat1(),Mouse1()]
for animal in animals:
    animal.speak()
    print(animal.alive)
# Out:
# Woof
# True
# Meow
# True
# squeak
# True

# %% [markdown]
# #Aggregation  = Represents a relationship where one object (the whole)
#                 contains references to one or more (Independent) objects
#
#                 (The parts)

# %%
class Library: #The whole
    def __init__(self,name):
        self.name = name
        self.books=[]
    def add_book(self,book):
        self.books.append(book)

    def list_books(self):
        return [f"{book.title} by {book.author}" for book in self.books]
    

class Book: #Independent
    def __init__(self,title,author):
        self.title = title
        self.author =author

library = Library ("New York Public Library")

book1 =Book("Thermodynamics","Cengel")
book2 = Book("The Hobbit","J. R. R. Tolkein")
book3 = Book("Harry Potter","J.K. Rowling")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

'''''
What it does

print(library.name) — prints the Library instance's name attribute.
for book in library.list_books(): print(book) — calls Library.list_books(), iterates the returned list, and prints each item.
Why it works in your notebook

Library.list_books() returns a list comprehension: [f"{book.title} by {book.author}" for book in self.books], 
so each item is a formatted string (not Book objects). The loop prints those strings.
'''''
print(library.name)
for book in library.list_books():
    print(book)

'''''
can also write , if return isn't specified
for book in library.list_books():
    print(f"{book.title} by {book.author}")
'''''
# Out:
# New York Public Library
# Thermodynamics by Cengel
# The Hobbit by J. R. R. Tolkein
# Harry Potter by J.K. Rowling
# '\'\'\ncan also write\nfor book in library.list_books():\n    print(f"{book.title} by {book.author}")\n'

# %% [markdown]
# #Composition = The composed object directly owns its components, which cannot exist independently "owns-a" relationship
#
#
#                             it owns  things where aggregation has things

# %%
class Engine:
    def __init__(self,horse_power):
     self.horse_power =horse_power

class Wheel:
   def __init__(self,size):
      self.size =size

class Car2:
   def __init__(self,make,model,horse_power,wheel_size):
      self.make = make
      self.model = model
      self.engine = Engine(horse_power) # contain within # Engine constructor
      self.wheels = [Wheel(wheel_size) for wheel in range(4)]
      #4 wheels total # creating whells and engine object inside Car2
      #it is list the wheels
   def display_car(self):
      return f"{self.make}, {self.model},{self.engine.horse_power}hp and the Wheel size is {self.wheels[0].size}in" #it is a string that is returning

car4 = Car2("Ford","Mustang",500,18)
print(car4.display_car())
# Out:
# Ford, Mustang,500hp and the Wheel size is 18in

# %% [markdown]
# # Nested Class

# %% [markdown]
# #Nested class = A class defined within another class
#
#                class Outer:
#                   class Inner:
#
#
# #Benifits : Allows you to logically group classes that are closely related
#
# #Encapsulates private details that aren't relevant outside of the outer class
#
# #Keeps the namespace clean; reduces the possibility of naming conflicts

# %%
class Company:
    class Employee:
        def __init__(self , name , position):
            self.name = name
            self.position = position
        
        def get_details(self):
            return f"{self.name} position: {self.position}"
        
    def __init__(self,company_name):
        self.company_name = company_name
        self.employees =[]
    
    def add_employee(self,name,position):
        new_employee = self.Employee(name,position)
        self.employees.append(new_employee)
    
    def list_employees(self):
        return [employee.get_details() for employee in self.employees]
    
    
company1 = Company("Krusty Krab")
company2 = Company("Chum Bucket")

company1.add_employee("Eugene", "Manager")
company1.add_employee("Spongebob", "Cook")
company1.add_employee("Squidward", "Cashier")

company2.add_employee("Sheldon", "Manager")
company2.add_employee("Karen", "Assistant")

for employee in company2.list_employees ():
    print(employee)
# Out:
# Sheldon position: Manager
# Karen position: Assistant

# %%
# Magic methods = Dunder methods (double underscore) __init__, __str__, __eq__
#                                 They are automatically called by many of Python's built-in operations.
#                                 They allow developers to define or customize the behavior of objects

class Book:

    def __init__(self, title, author, num_pages):
        self.title = title
        self.author = author
        self.num_pages = num_pages

    def __str__(self):
        return f"'{self.title}' by {self.author}"

    def __eq__(self, other):
        return self.title == other.title and self.author == other.author

    def __lt__(self, other):
        return self.num_pages < other.num_pages

    def __gt__(self, other):
        return self.num_pages > other.num_pages

    def __add__(self, other):
        return f"{self.num_pages + other.num_pages} pages"

    def __contains__(self, keyword):
        return keyword in self.title or keyword in self.author

    def __getitem__(self, key):
        if key == "title":
            return self.title
        elif key == "author":
            return self.author
        elif key == "num_pages":
            return self.num_pages
        else:
            return f"Key '{key}' was not found"

book1 = Book("The Hobbit", "J.R.R. Tolkien", 310)
book2 = Book("Harry Potter and The Philosopher's Stone", "J.K. Rowling", 223)
book3 = Book("The Lion, the Witch and the Wardrobe", "C.S. Lewis", 172)

print(book1)  # Calls __str__
print(book1 == book3)  # Calls __eq__
print(book1 < book2)  # Calls ___lt__
print(book2 > book3)  # Calls __gt__
print(book1 + book2)  # Calls __add__
print("Lion" in book3)  # Calls __contains__
print(book3['title'])  # Calls __getitem__
# Out:
# 'The Hobbit' by J.R.R. Tolkien
# False
# False
# True
# 533 pages
# True
# The Lion, the Witch and the Wardrobe
